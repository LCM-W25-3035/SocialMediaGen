# %%
# !pip install requests beautifulsoup4
# !pip install pymongo
# Out:
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (2.32.3)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.11/dist-packages (4.12.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests) (2024.12.14)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.11/dist-packages (from beautifulsoup4) (2.6)
# Collecting pymongo
#   Downloading pymongo-4.10.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (22 kB)
# Collecting dnspython<3.0.0,>=1.16.0 (from pymongo)
#   Downloading dnspython-2.7.0-py3-none-any.whl.metadata (5.8 kB)
# Downloading pymongo-4.10.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 20.7 MB/s eta 0:00:00
# Downloading dnspython-2.7.0-py3-none-any.whl (313 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 313.6/313.6 kB 19.4 MB/s eta 0:00:00
# Installing collected packages: dnspython, pymongo
# Successfully installed dnspython-2.7.0 pymongo-4.10.1

# %%
import requests
from bs4 import BeautifulSoup
from pymongo import MongoClient, errors
import datetime

# Function to connect to MongoDB
def connect_mongo():
    try:
        client = MongoClient("mongodb+srv://Muskan:MUSKAN25@newsanalytics.rzmco.mongodb.net/?retryWrites=true&w=majority&appName=NEWSANALYTICS")
        db = client["news_database"]
        collection = db["bbc_headlines"]

        # Remove duplicate entries with empty or duplicate links before creating the index
        print("Cleaning up duplicate entries...")
        collection.delete_many({"link": ""})  # Remove records with empty links
        print("Removed empty links.")

        # Ensure unique index on the 'link' field
        collection.create_index("link", unique=True)
        print("Unique index created on 'link' field.")

        return collection
    except Exception as e:
        print("Error connecting to MongoDB:", e)
        return None

# Function to scrape BBC News headlines
def scrape_bbc_news():
    url = "https://www.bbc.com/news"

    headers = {
        "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36"
    }

    try:
        response = requests.get(url, headers=headers)

        if response.status_code == 200:
            soup = BeautifulSoup(response.text, 'html.parser')

            # Find all headlines
            headlines = soup.select('h2')

            if not headlines:
                print("No headlines found. The page structure may have changed.")
                return []

            news_list = []
            for headline in headlines:
                title = headline.get_text(strip=True)
                link_tag = headline.find_parent('a')  # Get the parent anchor tag for link
                link = link_tag['href'] if link_tag else ''
                full_link = f"https://www.bbc.com{link}" if link.startswith('/') else link

                # Skip empty links
                if full_link.strip():
                    news_list.append({
                        "title": title,
                        "link": full_link,
                        "scraped_at": datetime.datetime.now().isoformat()
                    })

            return news_list
        else:
            print(f"Failed to retrieve BBC News. Status code: {response.status_code}")
            return []

    except Exception as e:
        print("Error occurred while scraping BBC News:", e)
        return []

# Function to store news in MongoDB with deduplication
def store_in_mongo(news_data):
    collection = connect_mongo()
    if collection is not None:
        inserted_count = 0
        for news in news_data:
            try:
                collection.insert_one(news)
                inserted_count += 1
            except errors.DuplicateKeyError:
                print(f"Duplicate entry found, skipping: {news['title']}")

        print(f"Inserted {inserted_count} new articles into MongoDB.")
    else:
        print("Failed to connect to MongoDB.")

# Main function to run the scraper and store data
if __name__ == "__main__":
    print("Starting BBC News scraping...")
    news_data = scrape_bbc_news()

    if news_data:
        for news in news_data:
            print(f"Title: {news['title']}\nLink: {news['link']}\n")

        store_in_mongo(news_data)
    else:
        print("No news articles scraped.")
# Out:
# Starting BBC News scraping...
# Title: Nvidia shares sink as Chinese AI app spooks markets
# Link: https://www.bbc.com/news/articles/c0qw7z2v1pgo
#
# Title: Is China's AI tool DeepSeek as good as it seems?
# Link: https://www.bbc.com/news/articles/cx2jxvn0r51o
#
# Title: Palestinians return to north Gaza on foot, with belongings in hand
# Link: https://www.bbc.com/news/videos/cy5k03yq16lo
#
# Title: Belgian footballer Nainggolan arrested in cocaine trafficking sting
# Link: https://www.bbc.com/news/articles/c627zx21k94o
#
# Title: Holocaust survivors recall horrors of Auschwitz as Prince William and Kate attend London memorial
# Link: https://www.bbc.com/news/live/c5yep0l5545t
#
# Link: https://www.bbc.com/news/videos/cy5k03yq16lo
#
# Title: 'I was born in a concentration camp'
# Link: https://www.bbc.com/news/videos/cdjdzx97mm8o
#
# Title: Moment car accidentally drives into Philadelphia Eagles fans
# Link: https://www.bbc.com/news/videos/cpvmljj401ko
#
# Title: 'Medics told me I had no reason to be suicidal'
# Link: https://www.bbc.com/news/videos/ce3n22y3yd7o
#
# Title: Watch: Homes and nightclub raided in US immigration crackdown
# Link: https://www.bbc.com/news/videos/cq8ke58wpq5o
#
# Title: Belarus ruler claims landslide in 'sham' election
# Link: https://www.bbc.com/news/articles/cdjdzyzxd97o
#
# Title: New Zealand eases visa rules for 'digital nomads' to boost tourism
# Link: https://www.bbc.com/news/articles/cx2k7xvk2vvo
#
# Title: Colombia backs down and accepts US deportation flights to avert trade war
# Link: https://www.bbc.com/news/articles/c20p36e62gyo
#
# Title: Belgian footballer Nainggolan arrested in cocaine trafficking sting
# Link: https://www.bbc.com/news/articles/c627zx21k94o
#
# Title: Glasgow child sex abuse gang given life sentences
# Link: https://www.bbc.com/news/articles/c2dxj570n21o
#
# Title: New Zealand eases visa rules for 'digital nomads' to boost tourism
# Link: https://www.bbc.com/news/articles/cx2k7xvk2vvo
#
# Title: All missing monkeys returned after escape from US research lab
# Link: https://www.bbc.com/news/articles/c4gz27pp09vo
#
# Title: Mass arrests in nationwide US immigration crackdown
# Link: https://www.bbc.com/news/articles/cd6434dq7p1o
#
# Title: Colombia backs down and accepts US deportation flights to avert trade war
# Link: https://www.bbc.com/news/articles/c20p36e62gyo
#
# Title: Nvidia shares sink as Chinese AI app spooks markets
# Link: https://www.bbc.com/news/articles/c0qw7z2v1pgo
#
# Title: Denmark to spend billions more on Arctic security
# Link: https://www.bbc.com/news/articles/cly5661xd3no
#
# Title: Co-operate or else: Trump's Colombia face-off is warning to all leaders
# Link: https://www.bbc.com/news/articles/cglynrxjyl5o
#
# Title: Is China's AI tool DeepSeek as good as it seems?
# Link: https://www.bbc.com/news/articles/cx2jxvn0r51o
#
# Title: Israel says eight hostages due to be freed in first phase are dead
# Link: https://www.bbc.com/news/articles/ce3lynk8493o
#
# Title: Coca-Cola recalls drinks over safety concerns
# Link: https://www.bbc.com/news/articles/c3rwv9j74q9o
#
# Title: Couple defend first-cousin marriages amid ban call
# Link: https://www.bbc.com/news/articles/c4g38l07895o
#
# Title: Sweden seizes ship after suspected Baltic Sea cable sabotage
# Link: https://www.bbc.com/news/articles/cqx9g5wwp89o
#
# Title: Colombia yields on US deportation flights to avert trade war
# Link: https://www.bbc.com/news/articles/c20p36e62gyo
#
# Title: Belgian footballer Nainggolan arrested in cocaine trafficking sting
# Link: https://www.bbc.com/news/articles/c627zx21k94o
#
# Title: Referee Coote hid sexuality for fear of abuse
# Link: https://www.bbc.com/sport/football/articles/cx2p304d24do
#
# Title: 'No way back' for Rashford at Man Utd - Ferdinand
# Link: https://www.bbc.com/sport/football/articles/c2d3nj6237zo
#
# Title: Transfer spending up on last year with week to go
# Link: https://www.bbc.com/sport/football/articles/cj91z0zeklro
#
# Title: Are we in a golden age of the Six Nations?
# Link: https://www.bbc.co.uk/sport/extra/8ah6oemcah/Six-Nation-The-Golden-Age
#
# Title: Holders Ivory Coast to face Cameroon at Afcon 2025
# Link: https://www.bbc.com/sport/football/articles/cn7gz0e5gm8o
#
# Title: 'No way back' for Rashford at Man Utd - Ferdinand
# Link: https://www.bbc.com/sport/football/articles/c2d3nj6237zo
#
# Title: Butler suspended again after walking out of practice
# Link: https://www.bbc.com/sport/basketball/articles/cvgen8566yvo
#
# Title: Injury-hit Neymar has Al-Hilal contract terminated
# Link: https://www.bbc.com/sport/football/articles/c247r67g93qo
#
# Title: Transfer spending up on last year with week to go
# Link: https://www.bbc.com/sport/football/articles/cj91z0zeklro
#
# Cleaning up duplicate entries...
# Removed empty links.
# Unique index created on 'link' field.
# Duplicate entry found, skipping: Is China's AI tool DeepSeek as good as it seems?
# Duplicate entry found, skipping: Palestinians return to north Gaza on foot, with belongings in hand
# Duplicate entry found, skipping: Inside the race for Greenland's mineral wealth
# Duplicate entry found, skipping: Dam plan busted? World's biggest hydropower project in the balance
# Duplicate entry found, skipping: Palestinians return to north Gaza on foot, with belongings in hand
# Duplicate entry found, skipping: Moment car accidentally drives into Philadelphia Eagles fans
# Duplicate entry found, skipping: New Zealand eases visa rules for 'digital nomads' to boost tourism
# Duplicate entry found, skipping: Colombia backs down and accepts US deportation flights to avert trade war
# Duplicate entry found, skipping: Belgian footballer Nainggolan arrested in cocaine trafficking sting
# Duplicate entry found, skipping: New Zealand eases visa rules for 'digital nomads' to boost tourism
# Duplicate entry found, skipping: All missing monkeys returned after escape from US research lab
# Duplicate entry found, skipping: Colombia backs down and accepts US deportation flights to avert trade war
# Duplicate entry found, skipping: Nvidia shares sink as Chinese AI app spooks markets
# Duplicate entry found, skipping: Denmark to spend billions more on Arctic security
# Duplicate entry found, skipping: Co-operate or else: Trump's Colombia face-off is warning to all leaders
# Duplicate entry found, skipping: Is China's AI tool DeepSeek as good as it seems?
# Duplicate entry found, skipping: Israel says eight hostages due to be freed in first phase are dead
# Duplicate entry found, skipping: Colombia yields on US deportation flights to avert trade war
# Duplicate entry found, skipping: Belgian footballer Nainggolan arrested in cocaine trafficking sting
# Duplicate entry found, skipping: 'No way back' for Rashford at Man Utd - Ferdinand
# Duplicate entry found, skipping: Transfer spending up on last year with week to go
# Inserted 40 new articles into MongoDB.
